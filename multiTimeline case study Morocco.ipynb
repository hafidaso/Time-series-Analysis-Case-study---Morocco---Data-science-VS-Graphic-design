# %% [markdown]
# # Importing packeges and data

# %%
# Python set up
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
# Load the csv data files into pandas dataframes
df = pd.read_csv("C:/Users/VIDA/multiTimeline (2).csv" , skiprows=1)

# %%
df.head()
# Out:
#          Week  data science: (Morocco)  Graphic design: (Morocco)  \
# 0  2017-05-28                        0                          2
# 1  2017-06-04                        1                          1
# 2  2017-06-11                        4                          2
# 3  2017-06-18                        3                          2
# 4  2017-06-25                        1                          2
#
#    medecin: (Morocco)
# 0                  60
# 1                  60
# 2                  60
# 3                  62
# 4                  46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Week                       261 non-null    object
#  1   data science: (Morocco)    261 non-null    int64
#  2   Graphic design: (Morocco)  261 non-null    int64
#  3   medecin: (Morocco)         261 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 8.3+ KB

# %%
df.columns = ['month' , 'data science' , 'graphic design' , 'medecin']

# %%
df.head()
# Out:
#         month  data science  graphic design  medecin
# 0  2017-05-28             0               2       60
# 1  2017-06-04             1               1       60
# 2  2017-06-11             4               2       60
# 3  2017-06-18             3               2       62
# 4  2017-06-25             1               2       46

# %%
df['month'] = pd.to_datetime(df['month'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   month           261 non-null    datetime64[ns]
#  1   data science    261 non-null    int64
#  2   graphic design  261 non-null    int64
#  3   medecin         261 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 8.3 KB

# %%
df.set_index('month', inplace=True)

# %%
df.head()
# Out:
#             data science  graphic design  medecin
# month
# 2017-05-28             0               2       60
# 2017-06-04             1               1       60
# 2017-06-11             4               2       60
# 2017-06-18             3               2       62
# 2017-06-25             1               2       46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 261 entries, 2017-05-28 to 2022-05-22
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data science    261 non-null    int64
#  1   graphic design  261 non-null    int64
#  2   medecin         261 non-null    int64
# dtypes: int64(3)
# memory usage: 8.2 KB

# %% [markdown]
# # Exploratory data analysis EDA

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df[['medecin']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# # Trends and Seasonality in Time series Data

# %%
df[['data science']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df[['graphic design']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
pd.concat([df[['graphic design']].rolling(12).mean(), df[['data science']].rolling(12).mean()], axis = 1)
# Out:
#             graphic design  data science
# month
# 2017-05-28             NaN           NaN
# 2017-06-04             NaN           NaN
# 2017-06-11             NaN           NaN
# 2017-06-18             NaN           NaN
# 2017-06-25             NaN           NaN
# ...                    ...           ...
# 2022-04-24        4.916667      6.416667
# 2022-05-01        5.250000      6.250000
# 2022-05-08        5.416667      6.500000
# 2022-05-15        5.500000      6.750000
# 2022-05-22        5.000000      6.083333
#
# [261 rows x 2 columns]

# %%
pd.concat([df[['graphic design']].rolling(12).mean(), df[['data science']].rolling(12).mean()], axis = 1).plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>
